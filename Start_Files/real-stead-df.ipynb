# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits

# %%
df = pd.read_csv("./all_data.csv")

# %%
df.head(10)
# Out:
#         Locality Type of property Subtype of property   Price  \
# 0  1000 Brussels             flat    flat---apartment  333500
# 1  1000 Brussels             flat    flat---apartment  379000
# 2  1000 Brussels             flat    flat---apartment  295000
# 3  1000 Brussels             flat                loft  635000
# 4  1000 Brussels             flat                loft  595000
# 5  1000 Brussels             flat              duplex  615000
# 6  1000 Brussels             flat              duplex  615000
# 7  1000 Brussels             flat    flat---apartment  515000
# 8  1000 Brussels             flat    flat---apartment  550000
# 9  1000 Brussels             flat    flat---apartment  355000
#
#   Number of bedrooms Livable surface Kitchen equipment Number of bathrooms  \
# 0                  2          100 m²    Super equipped                   1
# 1                  1           80 m²    Super equipped                   1
# 2                  2           80 m²              None                None
# 3                  2          217 m²    Super equipped                   1
# 4                  2          207 m²              None                   2
# 5                  2          170 m²    Super equipped                   1
# 6                  1          170 m²    Super equipped                   1
# 7                  3          130 m²              None                   2
# 8                  3          130 m²              None                   2
# 9                  1           82 m²    Fully equipped                   1
#
#   Number of toilets Floor of appartment  ... Veranda Barbecue  \
# 0                 1                   1  ...    None     None
# 1                 1                   3  ...    None     None
# 2                 1                None  ...    None     None
# 3                 3                   4  ...    None     None
# 4                 2                   3  ...    None     None
# 5                 2                None  ...    None     None
# 6                 2                None  ...    None     None
# 7              None                   1  ...    None     None
# 8              None                   4  ...    None     None
# 9              None                None  ...    None     None
#
#   Surface of the garage Water softener Terrain width at the roadside  \
# 0                  None           None                          None
# 1                  None           None                          None
# 2                  None           None                          None
# 3                  None           None                          None
# 4                  None           None                          None
# 5                  None           None                          None
# 6                  None           None                          None
# 7                  None           None                          None
# 8                  None           None                          None
# 9                  None           None                          None
#
#   Surface of the dressing Surface of the veranda Terrace orientation  \
# 0                    None                   None                None
# 1                    None                   None                None
# 2                    None                   None                None
# 3                    None                   None                None
# 4                    None                   None                None
# 5                    None                   None                None
# 6                    None                   None                None
# 7                    None                   None                None
# 8                    None                   None                None
# 9                    None                   None                None
#
#   Bike storage Lighting with motion sensor
# 0         None                        None
# 1         None                        None
# 2         None                        None
# 3         None                        None
# 4         None                        None
# 5         None                        None
# 6         None                        None
# 7         None                        None
# 8         None                        None
# 9         None                        None
#
# [10 rows x 80 columns]

# %%
flats = df.loc[df['Type of property'] =='flat', 'Garden']
flats.value_counts()
# Out:
# None    7954
# 1        857
# 0         71
# Name: Garden, dtype: int64

# %%
df.columns
# Out:
# Index(['Locality', 'Type of property', 'Subtype of property', 'Price',
#        'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
#        'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
#        'Number of floors', 'Balcony', 'State of the property',
#        'Currently leased', 'Build Year', 'Availability', 'Surface bedroom 1',
#        'Furnished', 'Surface of living-room', 'Cellar', 'Surface kitchen',
#        'Entry phone', 'Elevator', 'Number of showers',
#        'Orientation of the front facade', 'Number of facades', 'Terrace',
#        'Surface terrace', 'Surface bedroom 2', 'Security door',
#        'Access for disabled', 'Sewer Connection', 'Frontage width', 'Gas',
#        'Office surface', 'Total land surface', 'Kitchen type', 'Garden',
#        'Surface garden', 'Surface bedroom 3', 'Garage', 'Number of garages',
#        'Diningroom', 'Surface of the diningroom', 'Dressing', 'Electronic key',
#        'Surface bedroom 4', 'Surface bedroom 5', 'Surface of the bathroom(s)',
#        'Swimming pool', 'Surface of the dressing'],
#       dtype='object')

# %%
plt.scatter(tail['Terrace'], tail['Price'])
plt.title("Locality vs Price")
# Out:
# Text(0.5, 1.0, 'Locality vs Price')

# %%
df.drop(['Entry phone','Currently leased', 'Security door',
       'Access for disabled', 'Sewer Connection', 'Frontage width','Office surface'], axis=1, inplace=True)

# %%
df.head(12)

# %%
df.tail(12)

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Locality', 'Type of property', 'Subtype of property', 'Price',
#        'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
#        'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
#        'Number of floors', 'Balcony', 'State of the property',
#        'Currently leased', 'Build Year', 'Availability', 'Surface bedroom 1',
#        'Furnished', 'Surface of living-room', 'Cellar', 'Surface kitchen',
#        'Entry phone', 'Elevator', 'Number of showers',
#        'Orientation of the front facade', 'Number of facades', 'Terrace',
#        'Surface terrace', 'Surface bedroom 2', 'Security door',
#        'Access for disabled', 'Sewer Connection', 'Frontage width', 'Gas',
#        'Office surface', 'Total land surface', 'Kitchen type', 'Garden',
#        'Surface garden', 'Surface bedroom 3', 'Garage', 'Number of garages',
#        'Diningroom', 'Surface of the diningroom', 'Dressing', 'Wash room',
#        'Air conditioning', 'Domotica', 'Alarm', 'Hammam/Sauna/Jacuzzi',
#        'Fireplace', 'Buildable surface', 'Ground depth',
#        'Surface of the cellar(s)', 'Attic', 'Motorized garage door',
#        'Electronic key', 'Surface bedroom 4', 'Surface bedroom 5',
#        'Electric charging station', 'Number of parking spaces (indoor)',
#        'Number of parking places (outdoor)', 'Attic surface',
#        'Opportunity for professional', 'Surface of the bathroom(s)',
#        'Adaptations for elderlies', 'Service apartment', 'Garden orientation',
#        'Rain water tank', 'Swimming pool', 'Veranda', 'Barbecue',
#        'Surface of the garage', 'Water softener',
#        'Terrain width at the roadside', 'Surface of the dressing',
#        'Surface of the veranda', 'Terrace orientation', 'Bike storage',
#        'Lighting with motion sensor'],
#       dtype='object')

# %%
colum_uniq = ['Type of property', 'Subtype of property', 'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
       'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
       'Number of floors', 'Balcony', 'State of the property', 'Build Year',
       'Availability', 'Surface bedroom 1', 'Furnished',
       'Surface of living-room', 'Cellar', 'Surface kitchen', 'Elevator',
       'Number of showers', 'Orientation of the front facade',
       'Number of facades', 'Terrace', 'Surface terrace', 'Surface bedroom 2',
       'Gas', 'Total land surface', 'Kitchen type', 'Garden', 'Surface garden',
       'Surface bedroom 3', 'Garage', 'Number of garages', 'Diningroom',
       'Surface of the diningroom', 'Dressing', 'Electronic key',
       'Surface bedroom 4', 'Surface bedroom 5', 'Surface of the bathroom(s)',
       'Swimming pool', 'Surface of the dressing']

# %%
#subtype_of_property_unq_val = df['Subtype of property'].unique()
#print(subtype_of_property)

# %%
num_bedroom_unq_val = df['Number of bedrooms'].unique()
print(num_bedroom_unq_val)
# Out:
# ['2' '1' '3' '4' 'None' '5' '6' '8' '14' '10' '9' '12' '13' '7' '16' '11'
#  '20' '40' '23' '22' '15' '333']

# %%
df.loc[df['Number of bedrooms']=='333']    # they put wrong number of bedrom  3 bedrooms
# Out:
#              Locality Type of property Subtype of property   Price  \
# 15443  8650 Houthulst            house           residence  195000
#
#       Number of bedrooms Livable surface Kitchen equipment  \
# 15443                333          155 m²              None
#
#       Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# 15443                None                 1                None  ...    None
#
#       Barbecue Surface of the garage Water softener  \
# 15443     None                  None           None
#
#       Terrain width at the roadside Surface of the dressing  \
# 15443                          None                    None
#
#       Surface of the veranda Terrace orientation Bike storage  \
# 15443                   None                None         None
#
#       Lighting with motion sensor
# 15443                        None
#
# [1 rows x 80 columns]

# %%
df.loc[df['Number of bedrooms']=='None']
# Out:
#             Locality Type of property Subtype of property   Price  \
# 18     1000 Brussels             flat       flat---studio  180000
# 21     1000 Brussels             flat       flat---studio  165000
# 33     1000 Brussels             flat       flat---studio  165000
# 42     1000 Brussels             flat       flat---studio  185000
# 45     1000 Brussels             flat    flat---apartment  165000
# ...              ...              ...                 ...     ...
# 18102    9880 Aalter             flat    flat---apartment  226000
# 18176     9900 Eeklo            house           residence  484273
# 18315  9940 Ertvelde            house           residence  300000
# 18366  9970 Kaprijke             flat    flat---apartment    None
# 18396  9990 Maldegem             flat    flat---apartment  490000
#
#       Number of bedrooms Livable surface   Kitchen equipment  \
# 18                  None           40 m²  Partially equipped
# 21                  None           37 m²                None
# 33                  None           40 m²                None
# 42                  None           33 m²                None
# 45                  None           33 m²                None
# ...                  ...             ...                 ...
# 18102               None            None      Fully equipped
# 18176               None          164 m²                None
# 18315               None            None                None
# 18366               None            None                None
# 18396               None            None                None
#
#       Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# 18                      1                 1                None  ...    None
# 21                      1                 1                   2  ...    None
# 33                      1                 1                   2  ...    None
# 42                      1                 1                None  ...    None
# 45                      1                 1                None  ...    None
# ...                   ...               ...                 ...  ...     ...
# 18102                   1                 1                None  ...    None
# 18176                None              None                None  ...    None
# 18315                None              None                None  ...    None
# 18366                None              None                None  ...    None
# 18396                None              None                None  ...    None
#
#       Barbecue Surface of the garage Water softener  \
# 18        None                  None           None
# 21        None                  None           None
# 33        None                  None           None
# 42        None                  None           None
# 45        None                  None           None
# ...        ...                   ...            ...
# 18102     None                  None           None
# 18176     None                  None           None
# 18315     None                  None           None
# 18366     None                  None           None
# 18396     None                  None           None
#
#       Terrain width at the roadside Surface of the dressing  \
# 18                             None                    None
# 21                             None                    None
# 33                             None                    None
# 42                             None                    None
# 45                             None                    None
# ...                             ...                     ...
# 18102                          None                    None
# 18176                          None                    None
# 18315                          None                    None
# 18366                          None                    None
# 18396                          None                    None
#
#       Surface of the veranda Terrace orientation Bike storage  \
# 18                      None                None         None
# 21                      None                None         None
# 33                      None                None         None
# 42                      None                None         None
# 45                      None                None         None
# ...                      ...                 ...          ...
# 18102                   None                None         None
# 18176                   None                None         None
# 18315                   None                None         None
# 18366                   None                None         None
# 18396                   None                None         None
#
#       Lighting with motion sensor
# 18                           None
# 21                           None
# 33                           None
# 42                           None
# 45                           None
# ...                           ...
# 18102                        None
# 18176                        None
# 18315                        None
# 18366                        None
# 18396                        None
#
# [549 rows x 80 columns]

# %%
df.describe()
# Out:
#            Locality Type of property Subtype of property  Price  \
# count         18507            18507               18507  18507
# unique          900                2                  15   2823
# top     1050 Elsene            house           residence   None
# freq            331             9625                8004    654
#
#        Number of bedrooms Livable surface Kitchen equipment  \
# count               18507           18507             18507
# unique                 22             666                 5
# top                     2            None              None
# freq                 6209            2113              9500
#
#        Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# count                18507             18507               18507  ...   18507
# unique                  14                13                  31  ...       3
# top                      1                 1                None  ...    None
# freq                 12622              6940               13890  ...   18056
#
#        Barbecue Surface of the garage Water softener  \
# count     18507                 18507          18507
# unique        3                    66              3
# top        None                  None           None
# freq      18403                 18122          18376
#
#        Terrain width at the roadside Surface of the dressing  \
# count                          18507                   18507
# unique                            67                      17
# top                             None                    None
# freq                           17544                   18452
#
#        Surface of the veranda Terrace orientation Bike storage  \
# count                   18507               18507        18507
# unique                     11                   7            3
# top                      None                None         None
# freq                    18491               18472        18411
#
#        Lighting with motion sensor
# count                        18507
# unique                           3
# top                           None
# freq                         18479
#
# [4 rows x 80 columns]

# %%
df.loc[df['Price'] == None]
# Out:
# Empty DataFrame
# Columns: [Locality, Type of property, Subtype of property, Price, Number of bedrooms, Livable surface, Kitchen equipment, Number of bathrooms, Number of toilets, Floor of appartment, Number of floors, Balcony, State of the property, Currently leased, Build Year, Availability, Surface bedroom 1, Furnished, Surface of living-room, Cellar, Surface kitchen, Entry phone, Elevator, Number of showers, Orientation of the front facade, Number of facades, Terrace, Surface terrace, Surface bedroom 2, Security door, Access for disabled, Sewer Connection, Frontage width, Gas, Office surface, Total land surface, Kitchen type, Garden, Surface garden, Surface bedroom 3, Garage, Number of garages, Diningroom, Surface of the diningroom, Dressing, Electronic key, Surface bedroom 4, Surface bedroom 5, Surface of the bathroom(s), Swimming pool, Surface of the dressing]
# Index: []
#
# [0 rows x 51 columns]

# %%
freq_of_val = []
for name in column_names:
    if name in colum_uniq:
        freq_of_val.append(df[name].value_counts())
print(freq_of_val)
# Out:
# [house    9625
# flat     8882
# Name: Type of property, dtype: int64, residence           8004
# flat---apartment    7124
# villa                899
# ground-floor         522
# duplex               464
# penthouse            385
# mixed-building       368
# flat---studio        261
# master-house         138
# loft                  90
# cottage               89
# bungalow              81
# triplex               36
# chalet                26
# mansion               20
# Name: Subtype of property, dtype: int64, 2       6209
# 3       6001
# 4       2291
# 1       2050
# 5        808
# None     549
# 6        342
# 7        112
# 8         61
# 9         22
# 10        17
# 12        13
# 11        10
# 14         8
# 16         5
# 20         3
# 13         1
# 40         1
# 23         1
# 22         1
# 15         1
# 333        1
# Name: Number of bedrooms, dtype: int64, None      2113
# 100 m²     344
# 90 m²      307
# 150 m²     297
# 85 m²      290
#           ...
# 704 m²       1
# 578 m²       1
# 493 m²       1
# 542 m²       1
# 630 m²       1
# Name: Livable surface, Length: 666, dtype: int64, None                  9500
# Super equipped        4067
# Fully equipped        2967
# Partially equipped    1431
# Not equipped           542
# Name: Kitchen equipment, dtype: int64, 1       12622
# None     2821
# 2        2420
# 3         409
# 4         139
# 5          43
# 6          25
# 8           9
# 7           7
# 12          3
# 10          3
# 9           2
# 14          2
# 11          2
# Name: Number of bathrooms, dtype: int64, 1       6940
# None    6135
# 2       4267
# 3        779
# 4        239
# 5         77
# 6         40
# 8          9
# 10         7
# 7          6
# 12         3
# 14         3
# 9          2
# Name: Number of toilets, dtype: int64, None    13890
# 1        1508
# 2        1288
# 3         809
# 4         368
# 5         191
# 6         134
# 7         101
# 8          54
# 9          48
# 11         22
# 10         21
# 12         20
# 14          9
# 23          6
# 13          6
# 16          6
# 21          4
# 19          4
# 15          3
# -1          2
# 20          2
# 18          2
# 17          2
# 30          1
# 43          1
# 41          1
# 22          1
# 24          1
# -2          1
# 999         1
# Name: Floor of appartment, dtype: int64, None    10461
# 2        2404
# 3        2146
# 4        1144
# 1         923
# 5         376
# 6         319
# 7         225
# 8         156
# 12         76
# 9          70
# 10         66
# 11         28
# 15         22
# 25         17
# 16         12
# 13         11
# 20         10
# 26         10
# 18          7
# 14          6
# 17          3
# 22          3
# 21          2
# 27          2
# 23          2
# 19          2
# 34          1
# 35          1
# 41          1
# 24          1
# Name: Number of floors, dtype: int64, None    16090
# 0        2041
# 1         376
# Name: Balcony, dtype: int64, New                5156
# None               4346
# Normal             3931
# Excellent          2665
# To be renovated    2021
# Fully renovated     388
# Name: State of the property, dtype: int64, None    8809
# 2021    1286
# 2022     793
# 2020     556
# 2019     247
#         ...
# 1895       1
# 1889       1
# 1678       1
# 1897       1
# 1660       1
# Name: Build Year, Length: 182, dtype: int64, None               8749
# On contract        6603
# Negotiable         1489
# Immediately        1320
# From 30/12/2023      39
#                    ...
# From 30/11/2021       1
# From 15/02/2021       1
# From 01/06/2023       1
# From 11/10/2021       1
# From 30/06/2020       1
# Name: Availability, Length: 111, dtype: int64, None      13277
# 15 m²       584
# 14 m²       572
# 16 m²       528
# 13 m²       498
#           ...
# 98 m²         1
# 100 m²        1
# 64 m²         1
# 104 m²        1
# 73 m²         1
# Name: Surface bedroom 1, Length: 81, dtype: int64, 0       11446
# None     6629
# 1         432
# Name: Furnished, dtype: int64, None      11240
# 30 m²       586
# 35 m²       360
# 40 m²       344
# 25 m²       320
#           ...
# 130 m²        1
# 445 m²        1
# 210 m²        1
# 79 m²         1
# 162 m²        1
# Name: Surface of living-room, Length: 129, dtype: int64, None    13972
# 1        4401
# 0         134
# Name: Cellar, dtype: int64, None      15129
# 10 m²       316
# 8 m²        305
# 12 m²       263
# 9 m²        257
#           ...
# 49 m²         1
# 40 m²         1
# 43 m²         1
# 175 m²        1
# 54 m²         1
# Name: Surface kitchen, Length: 66, dtype: int64, 0       7200
# None    6353
# 1       4954
# Name: Elevator, dtype: int64, None    14718
# 1        3050
# 2         551
# 3         120
# 4          35
# 5          13
# 6           8
# 8           3
# 12          2
# 7           2
# 112         1
# 14          1
# 10          1
# 9           1
# 21          1
# Name: Number of showers, dtype: int64, None          12999
# South          1416
# South-west      995
# South-east      688
# West            626
# East            554
# North-west      431
# North-east      400
# North           398
# Name: Orientation of the front facade, dtype: int64, None    6690
# 2       5721
# 3       3193
# 4       2877
# 1         24
# 43         1
# 6          1
# Name: Number of facades, dtype: int64, None    10479
# 1        7845
# 0         183
# Name: Terrace, dtype: int64, None      11432
# 10 m²       406
# 8 m²        381
# 20 m²       376
# 15 m²       340
#           ...
# 83 m²         1
# 280 m²        1
# 112 m²        1
# 340 m²        1
# 537 m²        1
# Name: Surface terrace, Length: 147, dtype: int64, None       13949
# 12 m²        548
# 14 m²        482
# 13 m²        464
# 11 m²        428
# 15 m²        420
# 10 m²        393
# 16 m²        350
# 9 m²         283
# 17 m²        202
# 18 m²        163
# 20 m²        131
# 8 m²         115
# 19 m²        103
# 21 m²         76
# 22 m²         49
# 7 m²          48
# 0 m²          46
# 23 m²         38
# 24 m²         31
# 25 m²         25
# 26 m²         24
# 6 m²          21
# 28 m²         14
# 30 m²         13
# 5 m²          13
# 27 m²         11
# 35 m²          9
# 29 m²          7
# 33 m²          6
# 40 m²          5
# 31 m²          4
# 32 m²          4
# 1 m²           4
# 34 m²          3
# 38 m²          2
# 42 m²          2
# 37 m²          2
# 226 m²         2
# 49 m²          1
# 2 m²           1
# 1407 m²        1
# 166 m²         1
# 75 m²          1
# 56 m²          1
# 155 m²         1
# 77 m²          1
# 126 m²         1
# 1282 m²        1
# 132 m²         1
# 1583 m²        1
# 76 m²          1
# 39 m²          1
# 92 m²          1
# 67 m²          1
# 73 m²          1
# Name: Surface bedroom 2, dtype: int64, None    10368
# 1        7236
# 0         903
# Name: Gas, dtype: int64, None       10852
# 150 m²        58
# 200 m²        54
# 100 m²        49
# 130 m²        48
#            ...
# 1034 m²        1
# 62 m²          1
# 1445 m²        1
# 49 m²          1
# 2604 m²        1
# Name: Total land surface, Length: 1947, dtype: int64, None               17962
# Western kitchen      343
# Independent          169
# Kitchenette           31
# No kitchen             2
# Name: Kitchen type, dtype: int64, None    14186
# 1        4217
# 0         104
# Name: Garden, dtype: int64, None       15670
# 100 m²        72
# 50 m²         67
# 200 m²        66
# 40 m²         52
#            ...
# 515 m²         1
# 535 m²         1
# 384 m²         1
# 299 m²         1
# 2940 m²        1
# Name: Surface garden, Length: 700, dtype: int64, None       15699
# 12 m²        300
# 14 m²        267
# 10 m²        263
# 13 m²        245
# 11 m²        231
# 15 m²        207
# 16 m²        186
# 9 m²         183
# 17 m²        119
# 8 m²         118
# 20 m²         93
# 18 m²         93
# 7 m²          65
# 21 m²         55
# 19 m²         53
# 25 m²         43
# 22 m²         37
# 6 m²          33
# 24 m²         33
# 0 m²          23
# 23 m²         21
# 30 m²         20
# 28 m²         13
# 40 m²         12
# 27 m²         11
# 5 m²          11
# 26 m²         11
# 35 m²         10
# 29 m²          8
# 31 m²          5
# 44 m²          4
# 33 m²          4
# 32 m²          4
# 34 m²          3
# 48 m²          2
# 73 m²          2
# 38 m²          2
# 50 m²          2
# 36 m²          2
# 4 m²           2
# 135 m²         1
# 169 m²         1
# 3 m²           1
# 39 m²          1
# 1575 m²        1
# 45 m²          1
# 121 m²         1
# 58 m²          1
# 100 m²         1
# 1474 m²        1
# 41 m²          1
# 1 m²           1
# Name: Surface bedroom 3, dtype: int64, None    11961
# 1        6546
# Name: Garage, dtype: int64, None    12678
# 1        5301
# 2         413
# 3          67
# 4          23
# 5           7
# 16          6
# 6           4
# 63          1
# 19          1
# 15          1
# 8           1
# 10          1
# 11          1
# 26          1
# 25          1
# Name: Number of garages, dtype: int64, None    18402
# 0          71
# 1          34
# Name: Diningroom, dtype: int64, None     18487
# 15 m²        4
# 19 m²        2
# 21 m²        2
# 18 m²        1
# 20 m²        1
# 26 m²        1
# 1 m²         1
# 30 m²        1
# 12 m²        1
# 80 m²        1
# 22 m²        1
# 11 m²        1
# 34 m²        1
# 60 m²        1
# 17 m²        1
# Name: Surface of the diningroom, dtype: int64, None    18085
# 1         333
# 0          89
# Name: Dressing, dtype: int64, None    17852
# 0         637
# 1          18
# Name: Electronic key, dtype: int64, None       17354
# 12 m²        121
# 14 m²        109
# 13 m²        106
# 15 m²         92
# 10 m²         78
# 16 m²         76
# 11 m²         71
# 9 m²          62
# 17 m²         59
# 20 m²         50
# 18 m²         43
# 21 m²         38
# 8 m²          30
# 19 m²         26
# 7 m²          22
# 22 m²         21
# 23 m²         21
# 25 m²         20
# 24 m²         16
# 27 m²         12
# 28 m²          9
# 6 m²           8
# 30 m²          7
# 35 m²          6
# 26 m²          5
# 34 m²          5
# 40 m²          4
# 32 m²          3
# 45 m²          3
# 31 m²          3
# 0 m²           3
# 48 m²          2
# 50 m²          2
# 5 m²           2
# 58 m²          2
# 38 m²          2
# 4 m²           1
# 1 m²           1
# 66 m²          1
# 56 m²          1
# 43 m²          1
# 52 m²          1
# 29 m²          1
# 1277 m²        1
# 1173 m²        1
# 36 m²          1
# 37 m²          1
# 33 m²          1
# 125 m²         1
# 73 m²          1
# Name: Surface bedroom 4, dtype: int64, None      18069
# 15 m²        36
# 13 m²        35
# 12 m²        34
# 16 m²        31
# 11 m²        31
# 10 m²        30
# 14 m²        29
# 9 m²         21
# 20 m²        19
# 17 m²        19
# 8 m²         15
# 21 m²        14
# 18 m²        14
# 19 m²        13
# 22 m²        11
# 27 m²         8
# 25 m²         8
# 24 m²         8
# 23 m²         8
# 30 m²         5
# 7 m²          5
# 28 m²         4
# 5 m²          4
# 26 m²         4
# 36 m²         3
# 35 m²         3
# 45 m²         3
# 33 m²         2
# 6 m²          2
# 34 m²         2
# 29 m²         2
# 172 m²        1
# 40 m²         1
# 31 m²         1
# 0 m²          1
# 32 m²         1
# 41 m²         1
# 65 m²         1
# 50 m²         1
# 56 m²         1
# 42 m²         1
# 54 m²         1
# 77 m²         1
# 52 m²         1
# 37 m²         1
# 73 m²         1
# Name: Surface bedroom 5, dtype: int64, None     18391
# 0 m²        84
# 5 m²         9
# 6 m²         6
# 8 m²         5
# 7 m²         4
# 9 m²         2
# 10 m²        2
# 13 m²        1
# 12 m²        1
# 21 m²        1
# 15 m²        1
# Name: Surface of the bathroom(s), dtype: int64, None    18116
# 0         256
# 1         135
# Name: Swimming pool, dtype: int64, None     18452
# 6 m²        10
# 4 m²         8
# 10 m²        6
# 9 m²         5
# 7 m²         5
# 5 m²         4
# 8 m²         4
# 3 m²         3
# 15 m²        2
# 12 m²        2
# 1 m²         1
# 16 m²        1
# 14 m²        1
# 13 m²        1
# 11 m²        1
# 17 m²        1
# Name: Surface of the dressing, dtype: int64]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18507 entries, 0 to 18506
# Data columns (total 80 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Locality                            18507 non-null  object
#  1   Type of property                    18507 non-null  object
#  2   Subtype of property                 18507 non-null  object
#  3   Price                               18507 non-null  object
#  4   Number of bedrooms                  18507 non-null  object
#  5   Livable surface                     18507 non-null  object
#  6   Kitchen equipment                   18507 non-null  object
#  7   Number of bathrooms                 18507 non-null  object
#  8   Number of toilets                   18507 non-null  object
#  9   Floor of appartment                 18507 non-null  object
#  10  Number of floors                    18507 non-null  object
#  11  Balcony                             18507 non-null  object
#  12  State of the property               18507 non-null  object
#  13  Currently leased                    18507 non-null  object
#  14  Build Year                          18507 non-null  object
#  15  Availability                        18507 non-null  object
#  16  Surface bedroom 1                   18507 non-null  object
#  17  Furnished                           18507 non-null  object
#  18  Surface of living-room              18507 non-null  object
#  19  Cellar                              18507 non-null  object
#  20  Surface kitchen                     18507 non-null  object
#  21  Entry phone                         18507 non-null  object
#  22  Elevator                            18507 non-null  object
#  23  Number of showers                   18507 non-null  object
#  24  Orientation of the front facade     18507 non-null  object
#  25  Number of facades                   18507 non-null  object
#  26  Terrace                             18507 non-null  object
#  27  Surface terrace                     18507 non-null  object
#  28  Surface bedroom 2                   18507 non-null  object
#  29  Security door                       18507 non-null  object
#  30  Access for disabled                 18507 non-null  object
#  31  Sewer Connection                    18507 non-null  object
#  32  Frontage width                      18507 non-null  object
#  33  Gas                                 18507 non-null  object
#  34  Office surface                      18507 non-null  object
#  35  Total land surface                  18507 non-null  object
#  36  Kitchen type                        18507 non-null  object
#  37  Garden                              18507 non-null  object
#  38  Surface garden                      18507 non-null  object
#  39  Surface bedroom 3                   18507 non-null  object
#  40  Garage                              18507 non-null  object
#  41  Number of garages                   18507 non-null  object
#  42  Diningroom                          18507 non-null  object
#  43  Surface of the diningroom           18507 non-null  object
#  44  Dressing                            18507 non-null  object
#  45  Wash room                           18507 non-null  object
#  46  Air conditioning                    18507 non-null  object
#  47  Domotica                            18507 non-null  object
#  48  Alarm                               18507 non-null  object
#  49  Hammam/Sauna/Jacuzzi                18507 non-null  object
#  50  Fireplace                           18507 non-null  object
#  51  Buildable surface                   18507 non-null  object
#  52  Ground depth                        18507 non-null  object
#  53  Surface of the cellar(s)            18507 non-null  object
#  54  Attic                               18507 non-null  object
#  55  Motorized garage door               18507 non-null  object
#  56  Electronic key                      18507 non-null  object
#  57  Surface bedroom 4                   18507 non-null  object
#  58  Surface bedroom 5                   18507 non-null  object
#  59  Electric charging station           18507 non-null  object
#  60  Number of parking spaces (indoor)   18507 non-null  object
#  61  Number of parking places (outdoor)  18507 non-null  object
#  62  Attic surface                       18507 non-null  object
#  63  Opportunity for professional        18507 non-null  object
#  64  Surface of the bathroom(s)          18507 non-null  object
#  65  Adaptations for elderlies           18507 non-null  object
#  66  Service apartment                   18507 non-null  object
#  67  Garden orientation                  18507 non-null  object
#  68  Rain water tank                     18507 non-null  object
#  69  Swimming pool                       18507 non-null  object
#  70  Veranda                             18507 non-null  object
#  71  Barbecue                            18507 non-null  object
#  72  Surface of the garage               18507 non-null  object
#  73  Water softener                      18507 non-null  object
#  74  Terrain width at the roadside       18507 non-null  object
#  75  Surface of the dressing             18507 non-null  object
#  76  Surface of the veranda              18507 non-null  object
#  77  Terrace orientation                 18507 non-null  object
#  78  Bike storage                        18507 non-null  object
#  79  Lighting with motion sensor         18507 non-null  object
# dtypes: object(80)
# memory usage: 11.3+ MB
