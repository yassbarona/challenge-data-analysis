# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits

# %%
missing_val = ["None"]
df = pd.read_csv('all_data.csv', na_values = missing_val)

# %%
df.isnull().sum()
# Out:
# Locality                           0
# Type of property                   0
# Subtype of property                0
# Price                            654
# Number of bedrooms               549
#                                ...
# Surface of the dressing        18452
# Surface of the veranda         18491
# Terrace orientation            18472
# Bike storage                   18411
# Lighting with motion sensor    18479
# Length: 80, dtype: int64

# %%
#df.duplicated(subset=None, keep='first')
#df[df.duplicated(subset=None, keep=False)]
df[df.duplicated()]
# Out:
#               Locality Type of property Subtype of property   Price  \
# 309      1000 Brussels             flat    flat---apartment  295000
# 360         1020 Laken             flat                loft  239500
# 372         1020 Laken            house           residence  239500
# 420         1020 Laken             flat    flat---apartment  179500
# 455    1030 Schaarbeek             flat    flat---apartment  239000
# ...                ...              ...                 ...     ...
# 18489      9991 Adegem             flat    flat---apartment     NaN
# 18494      9991 Adegem             flat    flat---apartment     NaN
# 18496      9991 Adegem             flat    flat---apartment     NaN
# 18499      9991 Adegem             flat    flat---apartment     NaN
# 18501      9991 Adegem             flat    flat---apartment     NaN
#
#        Number of bedrooms Livable surface Kitchen equipment  \
# 309                   NaN           83 m²               NaN
# 360                   4.0          213 m²               NaN
# 372                   4.0          213 m²               NaN
# 420                   2.0           75 m²               NaN
# 455                   2.0           80 m²               NaN
# ...                   ...             ...               ...
# 18489                 1.0           59 m²    Fully equipped
# 18494                 1.0           56 m²    Fully equipped
# 18496                 1.0           74 m²    Fully equipped
# 18499                 2.0           85 m²    Fully equipped
# 18501                 1.0           68 m²    Fully equipped
#
#        Number of bathrooms  Number of toilets  Floor of appartment  ...  \
# 309                    NaN                NaN                  3.0  ...
# 360                    1.0                NaN                  NaN  ...
# 372                    1.0                NaN                  NaN  ...
# 420                    1.0                NaN                  1.0  ...
# 455                    NaN                1.0                  NaN  ...
# ...                    ...                ...                  ...  ...
# 18489                  1.0                1.0                  1.0  ...
# 18494                  1.0                1.0                  NaN  ...
# 18496                  1.0                1.0                  1.0  ...
# 18499                  1.0                1.0                  2.0  ...
# 18501                  1.0                1.0                  NaN  ...
#
#        Veranda  Barbecue Surface of the garage  Water softener  \
# 309        NaN       NaN                   NaN             NaN
# 360        NaN       NaN                   NaN             NaN
# 372        NaN       NaN                   NaN             NaN
# 420        NaN       NaN                   NaN             NaN
# 455        NaN       NaN                   NaN             NaN
# ...        ...       ...                   ...             ...
# 18489      NaN       NaN                   NaN             NaN
# 18494      NaN       NaN                   NaN             NaN
# 18496      NaN       NaN                   NaN             NaN
# 18499      NaN       NaN                   NaN             NaN
# 18501      NaN       NaN                   NaN             NaN
#
#        Terrain width at the roadside Surface of the dressing  \
# 309                              NaN                     NaN
# 360                              NaN                     NaN
# 372                              NaN                     NaN
# 420                              NaN                     NaN
# 455                              NaN                     NaN
# ...                              ...                     ...
# 18489                            NaN                     NaN
# 18494                            NaN                     NaN
# 18496                            NaN                     NaN
# 18499                            NaN                     NaN
# 18501                            NaN                     NaN
#
#       Surface of the veranda  Terrace orientation Bike storage  \
# 309                      NaN                  NaN          NaN
# 360                      NaN                  NaN          NaN
# 372                      NaN                  NaN          NaN
# 420                      NaN                  NaN          NaN
# 455                      NaN                  NaN          NaN
# ...                      ...                  ...          ...
# 18489                    NaN                  NaN          NaN
# 18494                    NaN                  NaN          NaN
# 18496                    NaN                  NaN          NaN
# 18499                    NaN                  NaN          NaN
# 18501                    NaN                  NaN          NaN
#
#        Lighting with motion sensor
# 309                            NaN
# 360                            NaN
# 372                            NaN
# 420                            NaN
# 455                            NaN
# ...                            ...
# 18489                          NaN
# 18494                          NaN
# 18496                          NaN
# 18499                          NaN
# 18501                          NaN
#
# [500 rows x 80 columns]

# %%
df_no_dupl = df.drop_duplicates(subset=None, keep='first', ignore_index = True)
df_no_dupl[df_no_dupl.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Locality, Type of property, Subtype of property, Price, Number of bedrooms, Livable surface, Kitchen equipment, Number of bathrooms, Number of toilets, Floor of appartment, Number of floors, Balcony, State of the property, Currently leased, Build Year, Availability, Surface bedroom 1, Furnished, Surface of living-room, Cellar, Surface kitchen, Entry phone, Elevator, Number of showers, Orientation of the front facade, Number of facades, Terrace, Surface terrace, Surface bedroom 2, Security door, Access for disabled, Sewer Connection, Frontage width, Gas, Office surface, Total land surface, Kitchen type, Garden, Surface garden, Surface bedroom 3, Garage, Number of garages, Diningroom, Surface of the diningroom, Dressing, Wash room, Air conditioning, Domotica, Alarm, Hammam/Sauna/Jacuzzi, Fireplace, Buildable surface, Ground depth, Surface of the cellar(s), Attic, Motorized garage door, Electronic key, Surface bedroom 4, Surface bedroom 5, Electric charging station, Number of parking spaces (indoor), Number of parking places (outdoor), Attic surface, Opportunity for professional, Surface of the bathroom(s), Adaptations for elderlies, Service apartment, Garden orientation, Rain water tank, Swimming pool, Veranda, Barbecue, Surface of the garage, Water softener, Terrain width at the roadside, Surface of the dressing, Surface of the veranda, Terrace orientation, Bike storage, Lighting with motion sensor]
# Index: []
#
# [0 rows x 80 columns]

# %%
df_no_dupl['Locality'].unique()
for vill in df_no_dupl['Locality'].unique():
    for vill2 in df_no_dupl['Locality'].unique():
        if vill[0:4] == vill2[0:4]:
            if vill != vill2:
                print(f"{vill} and {vill2}")

# %%
df_no_dupl.columns
# Out:
# Index(['Locality', 'Type of property', 'Subtype of property', 'Price',
#        'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
#        'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
#        'Number of floors', 'Balcony', 'State of the property',
#        'Currently leased', 'Build Year', 'Availability', 'Surface bedroom 1',
#        'Furnished', 'Surface of living-room', 'Cellar', 'Surface kitchen',
#        'Entry phone', 'Elevator', 'Number of showers',
#        'Orientation of the front facade', 'Number of facades', 'Terrace',
#        'Surface terrace', 'Surface bedroom 2', 'Security door',
#        'Access for disabled', 'Sewer Connection', 'Frontage width', 'Gas',
#        'Office surface', 'Total land surface', 'Kitchen type', 'Garden',
#        'Surface garden', 'Surface bedroom 3', 'Garage', 'Number of garages',
#        'Diningroom', 'Surface of the diningroom', 'Dressing', 'Electronic key',
#        'Surface bedroom 4', 'Surface bedroom 5', 'Surface of the bathroom(s)',
#        'Swimming pool', 'Surface of the dressing'],
#       dtype='object')

# %%
all_cols = df_no_dupl.columns
colls_to_keep = ['Locality', 'Type of property', 'Subtype of property', 'Price',
       'Number of bedrooms', 'Livable surface', 'Kitchen equipment', 'Balcony',
       'State of the property', 'Furnished', 'Number of facades', 
       'Terrace', 'Surface terrace', 'Total land surface', 'Garden', 'Surface garden',
       'Fireplace', 'Swimming pool']
colls_to_drop = []
for item in all_cols:
    if item not in colls_to_keep:
        colls_to_drop.append(item)
df_18_base = df_no_dupl.drop(colls_to_drop, axis=1, inplace=False)
df_18_base
# Out:
#               Locality Type of property Subtype of property    Price  \
# 0        1000 Brussels             flat    flat---apartment   333500
# 1        1000 Brussels             flat    flat---apartment   379000
# 2        1000 Brussels             flat    flat---apartment   295000
# 3        1000 Brussels             flat                loft   635000
# 4        1000 Brussels             flat                loft   595000
# ...                ...              ...                 ...      ...
# 18002  9992 Middelburg            house               villa   675000
# 18003  9992 Middelburg            house               villa  1450000
# 18004  9992 Middelburg            house           residence   695000
# 18005  9992 Middelburg            house           residence   420000
# 18006  9992 Middelburg            house           residence      NaN
#
#        Number of bedrooms Livable surface Kitchen equipment  Balcony  \
# 0                     2.0          100 m²    Super equipped      0.0
# 1                     1.0           80 m²    Super equipped      NaN
# 2                     2.0           80 m²               NaN      NaN
# 3                     2.0          217 m²    Super equipped      NaN
# 4                     2.0          207 m²               NaN      NaN
# ...                   ...             ...               ...      ...
# 18002                 3.0             NaN               NaN      NaN
# 18003                 6.0          630 m²               NaN      NaN
# 18004                 3.0          196 m²    Fully equipped      NaN
# 18005                 3.0             NaN               NaN      0.0
# 18006                 4.0             NaN               NaN      NaN
#
#       State of the property  Furnished  Number of facades  Terrace  \
# 0                       NaN        NaN                NaN      NaN
# 1                    Normal        0.0                NaN      NaN
# 2                    Normal        0.0                2.0      1.0
# 3           Fully renovated        0.0                NaN      1.0
# 4           Fully renovated        0.0                2.0      1.0
# ...                     ...        ...                ...      ...
# 18002       To be renovated        0.0                NaN      1.0
# 18003             Excellent        0.0                NaN      NaN
# 18004                   NaN        0.0                NaN      NaN
# 18005                   NaN        NaN                2.0      NaN
# 18006                   New        NaN                4.0      NaN
#
#       Surface terrace Total land surface  Garden Surface garden  Fireplace  \
# 0                 NaN                NaN     NaN            NaN        NaN
# 1                 NaN                NaN     NaN            NaN        NaN
# 2                4 m²                NaN     NaN            NaN        NaN
# 3               40 m²                NaN     NaN            NaN        NaN
# 4               10 m²                NaN     NaN            NaN        NaN
# ...               ...                ...     ...            ...        ...
# 18002           20 m²            2820 m²     1.0            NaN        NaN
# 18003             NaN            7693 m²     NaN            NaN        NaN
# 18004             NaN            2940 m²     1.0        2940 m²        NaN
# 18005             NaN            1664 m²     NaN            NaN        NaN
# 18006             NaN            2604 m²     NaN            NaN        NaN
#
#        Swimming pool
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 18002            NaN
# 18003            NaN
# 18004            NaN
# 18005            NaN
# 18006            NaN
#
# [18007 rows x 18 columns]

# %%
#df['Kitchen equipment'].value_counts()
df_18_base = df_18_base.dropna(subset = ['Price', 'Number of bedrooms', 'Furnished'])
df_18_base['Swimming pool'] = df_18_base['Swimming pool'].fillna(0)
df_18_base.isna().sum()
# Out:
# Locality                     0
# Type of property             0
# Subtype of property          0
# Price                        0
# Number of bedrooms           0
# Livable surface            854
# Kitchen equipment         4946
# Balcony                  10277
# State of the property     1160
# Furnished                    0
# Number of facades         3496
# Terrace                   5661
# Surface terrace           6201
# Total land surface        6230
# Garden                    8176
# Surface garden            8845
# Fireplace                10332
# Swimming pool                0
# dtype: int64

# %%
df_18_base['State of the property'].value_counts()
# Out:
# Normal             3260
# New                3019
# Excellent          1882
# To be renovated    1477
# Fully renovated     217
# Name: State of the property, dtype: int64

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Locality', 'Type of property', 'Subtype of property', 'Price',
#        'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
#        'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
#        'Number of floors', 'Balcony', 'State of the property', 'Build Year',
#        'Availability', 'Surface bedroom 1', 'Furnished',
#        'Surface of living-room', 'Cellar', 'Surface kitchen', 'Elevator',
#        'Number of showers', 'Orientation of the front facade',
#        'Number of facades', 'Terrace', 'Surface terrace', 'Surface bedroom 2',
#        'Gas', 'Total land surface', 'Kitchen type', 'Garden', 'Surface garden',
#        'Surface bedroom 3', 'Garage', 'Number of garages', 'Diningroom',
#        'Surface of the diningroom', 'Dressing', 'Electronic key',
#        'Surface bedroom 4', 'Surface bedroom 5', 'Surface of the bathroom(s)',
#        'Swimming pool', 'Surface of the dressing'],
#       dtype='object')

# %%
colum_uniq = ['Type of property', 'Subtype of property', 'Number of bedrooms', 'Livable surface', 'Kitchen equipment',
       'Number of bathrooms', 'Number of toilets', 'Floor of appartment',
       'Number of floors', 'Balcony', 'State of the property', 'Build Year',
       'Availability', 'Surface bedroom 1', 'Furnished',
       'Surface of living-room', 'Cellar', 'Surface kitchen', 'Elevator',
       'Number of showers', 'Orientation of the front facade',
       'Number of facades', 'Terrace', 'Surface terrace', 'Surface bedroom 2',
       'Gas', 'Total land surface', 'Kitchen type', 'Garden', 'Surface garden',
       'Surface bedroom 3', 'Garage', 'Number of garages', 'Diningroom',
       'Surface of the diningroom', 'Dressing', 'Electronic key',
       'Surface bedroom 4', 'Surface bedroom 5', 'Surface of the bathroom(s)',
       'Swimming pool', 'Surface of the dressing']

# %%
#subtype_of_property_unq_val = df['Subtype of property'].unique()
#print(subtype_of_property)

# %%
kitchen_unq_val = df['Kitchen equipment'].unique()
kitchen_unq_val
# Out:
# array(['Super equipped', 'None', 'Fully equipped', 'Partially equipped',
#        'Not equipped'], dtype=object)

# %%
num_bedroom_unq_val = df['Number of bedrooms'].unique()
print(num_bedroom_unq_val)
# Out:
# ['2' '1' '3' '4' 'None' '5' '6' '8' '14' '10' '9' '12' '13' '7' '16' '11'
#  '20' '40' '23' '22' '15' '333']

# %%
df.loc[df['Number of bedrooms']=='333']    # they put wrong number of bedrom  3 bedrooms
# Out:
#              Locality Type of property Subtype of property   Price  \
# 15443  8650 Houthulst            house           residence  195000
#
#       Number of bedrooms Livable surface Kitchen equipment  \
# 15443                333          155 m²              None
#
#       Number of bathrooms Number of toilets Floor of appartment  ...  \
# 15443                None                 1                None  ...
#
#       Number of garages Diningroom Surface of the diningroom Dressing  \
# 15443                 2       None                      None     None
#
#       Electronic key Surface bedroom 4 Surface bedroom 5  \
# 15443           None              None              None
#
#       Surface of the bathroom(s) Swimming pool Surface of the dressing
# 15443                       None          None                    None
#
# [1 rows x 44 columns]

# %%
df.loc[df['Number of bedrooms']=='333']    # they put wrong number of bedrom  3 bedrooms
# Out:
#              Locality Type of property Subtype of property   Price  \
# 15443  8650 Houthulst            house           residence  195000
#
#       Number of bedrooms Livable surface Kitchen equipment  \
# 15443                333          155 m²              None
#
#       Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# 15443                None                 1                None  ...    None
#
#       Barbecue Surface of the garage Water softener  \
# 15443     None                  None           None
#
#       Terrain width at the roadside Surface of the dressing  \
# 15443                          None                    None
#
#       Surface of the veranda Terrace orientation Bike storage  \
# 15443                   None                None         None
#
#       Lighting with motion sensor
# 15443                        None
#
# [1 rows x 80 columns]

# %%
df.loc[df['Number of bedrooms']=='None']
# Out:
#             Locality Type of property Subtype of property   Price  \
# 18     1000 Brussels             flat       flat---studio  180000
# 21     1000 Brussels             flat       flat---studio  165000
# 33     1000 Brussels             flat       flat---studio  165000
# 42     1000 Brussels             flat       flat---studio  185000
# 45     1000 Brussels             flat    flat---apartment  165000
# ...              ...              ...                 ...     ...
# 18102    9880 Aalter             flat    flat---apartment  226000
# 18176     9900 Eeklo            house           residence  484273
# 18315  9940 Ertvelde            house           residence  300000
# 18366  9970 Kaprijke             flat    flat---apartment    None
# 18396  9990 Maldegem             flat    flat---apartment  490000
#
#       Number of bedrooms Livable surface   Kitchen equipment  \
# 18                  None           40 m²  Partially equipped
# 21                  None           37 m²                None
# 33                  None           40 m²                None
# 42                  None           33 m²                None
# 45                  None           33 m²                None
# ...                  ...             ...                 ...
# 18102               None            None      Fully equipped
# 18176               None          164 m²                None
# 18315               None            None                None
# 18366               None            None                None
# 18396               None            None                None
#
#       Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# 18                      1                 1                None  ...    None
# 21                      1                 1                   2  ...    None
# 33                      1                 1                   2  ...    None
# 42                      1                 1                None  ...    None
# 45                      1                 1                None  ...    None
# ...                   ...               ...                 ...  ...     ...
# 18102                   1                 1                None  ...    None
# 18176                None              None                None  ...    None
# 18315                None              None                None  ...    None
# 18366                None              None                None  ...    None
# 18396                None              None                None  ...    None
#
#       Barbecue Surface of the garage Water softener  \
# 18        None                  None           None
# 21        None                  None           None
# 33        None                  None           None
# 42        None                  None           None
# 45        None                  None           None
# ...        ...                   ...            ...
# 18102     None                  None           None
# 18176     None                  None           None
# 18315     None                  None           None
# 18366     None                  None           None
# 18396     None                  None           None
#
#       Terrain width at the roadside Surface of the dressing  \
# 18                             None                    None
# 21                             None                    None
# 33                             None                    None
# 42                             None                    None
# 45                             None                    None
# ...                             ...                     ...
# 18102                          None                    None
# 18176                          None                    None
# 18315                          None                    None
# 18366                          None                    None
# 18396                          None                    None
#
#       Surface of the veranda Terrace orientation Bike storage  \
# 18                      None                None         None
# 21                      None                None         None
# 33                      None                None         None
# 42                      None                None         None
# 45                      None                None         None
# ...                      ...                 ...          ...
# 18102                   None                None         None
# 18176                   None                None         None
# 18315                   None                None         None
# 18366                   None                None         None
# 18396                   None                None         None
#
#       Lighting with motion sensor
# 18                           None
# 21                           None
# 33                           None
# 42                           None
# 45                           None
# ...                           ...
# 18102                        None
# 18176                        None
# 18315                        None
# 18366                        None
# 18396                        None
#
# [549 rows x 80 columns]

# %%
df.describe()
# Out:
#            Locality Type of property Subtype of property  Price  \
# count         18507            18507               18507  18507
# unique          900                2                  15   2823
# top     1050 Elsene            house           residence   None
# freq            331             9625                8004    654
#
#        Number of bedrooms Livable surface Kitchen equipment  \
# count               18507           18507             18507
# unique                 22             666                 5
# top                     2            None              None
# freq                 6209            2113              9500
#
#        Number of bathrooms Number of toilets Floor of appartment  ... Veranda  \
# count                18507             18507               18507  ...   18507
# unique                  14                13                  31  ...       3
# top                      1                 1                None  ...    None
# freq                 12622              6940               13890  ...   18056
#
#        Barbecue Surface of the garage Water softener  \
# count     18507                 18507          18507
# unique        3                    66              3
# top        None                  None           None
# freq      18403                 18122          18376
#
#        Terrain width at the roadside Surface of the dressing  \
# count                          18507                   18507
# unique                            67                      17
# top                             None                    None
# freq                           17544                   18452
#
#        Surface of the veranda Terrace orientation Bike storage  \
# count                   18507               18507        18507
# unique                     11                   7            3
# top                      None                None         None
# freq                    18491               18472        18411
#
#        Lighting with motion sensor
# count                        18507
# unique                           3
# top                           None
# freq                         18479
#
# [4 rows x 80 columns]

# %%
df.loc[df['Price'] == None]
# Out:
# Empty DataFrame
# Columns: [Locality, Type of property, Subtype of property, Price, Number of bedrooms, Livable surface, Kitchen equipment, Number of bathrooms, Number of toilets, Floor of appartment, Number of floors, Balcony, State of the property, Currently leased, Build Year, Availability, Surface bedroom 1, Furnished, Surface of living-room, Cellar, Surface kitchen, Entry phone, Elevator, Number of showers, Orientation of the front facade, Number of facades, Terrace, Surface terrace, Surface bedroom 2, Security door, Access for disabled, Sewer Connection, Frontage width, Gas, Office surface, Total land surface, Kitchen type, Garden, Surface garden, Surface bedroom 3, Garage, Number of garages, Diningroom, Surface of the diningroom, Dressing, Electronic key, Surface bedroom 4, Surface bedroom 5, Surface of the bathroom(s), Swimming pool, Surface of the dressing]
# Index: []
#
# [0 rows x 51 columns]

# %%
freq_of_val = []
for name in column_names:
    if name in colum_uniq:
        freq_of_val.append(df[name].value_counts())
print(freq_of_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4ed6c1fa9a7b> in <module>
#       1 freq_of_val = []
# ----> 2 for name in column_names:
#       3     #if name in colum_uniq:
#       4     freq_of_val.append(df[name].value_counts())
#       5 print(freq_of_val)
#
# NameError: name 'column_names' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18507 entries, 0 to 18506
# Data columns (total 80 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Locality                            18507 non-null  object
#  1   Type of property                    18507 non-null  object
#  2   Subtype of property                 18507 non-null  object
#  3   Price                               18507 non-null  object
#  4   Number of bedrooms                  18507 non-null  object
#  5   Livable surface                     18507 non-null  object
#  6   Kitchen equipment                   18507 non-null  object
#  7   Number of bathrooms                 18507 non-null  object
#  8   Number of toilets                   18507 non-null  object
#  9   Floor of appartment                 18507 non-null  object
#  10  Number of floors                    18507 non-null  object
#  11  Balcony                             18507 non-null  object
#  12  State of the property               18507 non-null  object
#  13  Currently leased                    18507 non-null  object
#  14  Build Year                          18507 non-null  object
#  15  Availability                        18507 non-null  object
#  16  Surface bedroom 1                   18507 non-null  object
#  17  Furnished                           18507 non-null  object
#  18  Surface of living-room              18507 non-null  object
#  19  Cellar                              18507 non-null  object
#  20  Surface kitchen                     18507 non-null  object
#  21  Entry phone                         18507 non-null  object
#  22  Elevator                            18507 non-null  object
#  23  Number of showers                   18507 non-null  object
#  24  Orientation of the front facade     18507 non-null  object
#  25  Number of facades                   18507 non-null  object
#  26  Terrace                             18507 non-null  object
#  27  Surface terrace                     18507 non-null  object
#  28  Surface bedroom 2                   18507 non-null  object
#  29  Security door                       18507 non-null  object
#  30  Access for disabled                 18507 non-null  object
#  31  Sewer Connection                    18507 non-null  object
#  32  Frontage width                      18507 non-null  object
#  33  Gas                                 18507 non-null  object
#  34  Office surface                      18507 non-null  object
#  35  Total land surface                  18507 non-null  object
#  36  Kitchen type                        18507 non-null  object
#  37  Garden                              18507 non-null  object
#  38  Surface garden                      18507 non-null  object
#  39  Surface bedroom 3                   18507 non-null  object
#  40  Garage                              18507 non-null  object
#  41  Number of garages                   18507 non-null  object
#  42  Diningroom                          18507 non-null  object
#  43  Surface of the diningroom           18507 non-null  object
#  44  Dressing                            18507 non-null  object
#  45  Wash room                           18507 non-null  object
#  46  Air conditioning                    18507 non-null  object
#  47  Domotica                            18507 non-null  object
#  48  Alarm                               18507 non-null  object
#  49  Hammam/Sauna/Jacuzzi                18507 non-null  object
#  50  Fireplace                           18507 non-null  object
#  51  Buildable surface                   18507 non-null  object
#  52  Ground depth                        18507 non-null  object
#  53  Surface of the cellar(s)            18507 non-null  object
#  54  Attic                               18507 non-null  object
#  55  Motorized garage door               18507 non-null  object
#  56  Electronic key                      18507 non-null  object
#  57  Surface bedroom 4                   18507 non-null  object
#  58  Surface bedroom 5                   18507 non-null  object
#  59  Electric charging station           18507 non-null  object
#  60  Number of parking spaces (indoor)   18507 non-null  object
#  61  Number of parking places (outdoor)  18507 non-null  object
#  62  Attic surface                       18507 non-null  object
#  63  Opportunity for professional        18507 non-null  object
#  64  Surface of the bathroom(s)          18507 non-null  object
#  65  Adaptations for elderlies           18507 non-null  object
#  66  Service apartment                   18507 non-null  object
#  67  Garden orientation                  18507 non-null  object
#  68  Rain water tank                     18507 non-null  object
#  69  Swimming pool                       18507 non-null  object
#  70  Veranda                             18507 non-null  object
#  71  Barbecue                            18507 non-null  object
#  72  Surface of the garage               18507 non-null  object
#  73  Water softener                      18507 non-null  object
#  74  Terrain width at the roadside       18507 non-null  object
#  75  Surface of the dressing             18507 non-null  object
#  76  Surface of the veranda              18507 non-null  object
#  77  Terrace orientation                 18507 non-null  object
#  78  Bike storage                        18507 non-null  object
#  79  Lighting with motion sensor         18507 non-null  object
# dtypes: object(80)
# memory usage: 11.3+ MB
